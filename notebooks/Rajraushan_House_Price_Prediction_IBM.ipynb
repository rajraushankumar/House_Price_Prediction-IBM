# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../data/train.csv")

print("Dataset loaded successfully!")
print("Shape:", df.shape)

df.head()
# Out:
# Dataset loaded successfully!
# Shape: (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nDataset Information:")
df.info()
# Out:
# Dataset Shape: (1460, 81)
#
# Column Names:
# ...

# %%
print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nDataset Information:")
df.info()
# Out:
# Dataset Shape: (1460, 81)
#
# Column Names:
# ...

# %%
missing_values = df.isnull().sum().sort_values(ascending=False)

print("Columns with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with missing values:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
print("Target Column: SalePrice")

print("\nSalePrice Summary:")
print(df["SalePrice"].describe())
# Out:
# Target Column: SalePrice
#
# SalePrice Summary:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df["SalePrice"], kde=True)

plt.title("Distribution of House Sale Prices")
plt.xlabel("Sale Price")
plt.ylabel("Number of Houses")

plt.savefig(
    "../reports/saleprice_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
numeric_columns = df.select_dtypes(include=["int64", "float64"]).columns

print("Number of numerical columns:", len(numeric_columns))

print("\nNumerical columns:")
print(numeric_columns.tolist())
# Out:
# Number of numerical columns: 38
#
# Numerical columns:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
important_features = [
    "OverallQual",
    "GrLivArea",
    "GarageCars",
    "TotalBsmtSF",
    "1stFlrSF"
]

print(df[important_features + ["SalePrice"]].describe())
# Out:
#        OverallQual    GrLivArea   GarageCars  TotalBsmtSF     1stFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315  1515.463699     1.767123  1057.429452  1162.626712
# std       1.382997   525.480383     0.747315   438.705324   386.587738
# min       1.000000   334.000000     0.000000     0.000000   334.000000
# 25%       5.000000  1129.500000     1.000000   795.750000   882.000000
# 50%       6.000000  1464.000000     2.000000   991.500000  1087.000000
# 75%       7.000000  1776.750000     2.000000  1298.250000  1391.250000
# max      10.000000  5642.000000     4.000000  6110.000000  4692.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
correlation = df[important_features + ["SalePrice"]].corr()["SalePrice"].sort_values(
    ascending=False
)

print(correlation)
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    df[important_features + ["SalePrice"]].corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Between Important Features and SalePrice")

plt.savefig(
    "../reports/correlation_heatmap.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x="OverallQual", y="SalePrice", data=df)

plt.title("Overall Quality vs House Sale Price")
plt.xlabel("Overall Quality")
plt.ylabel("Sale Price")

plt.savefig(
    "../reports/overall_quality_vs_price.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    x="GrLivArea",
    y="SalePrice",
    data=df
)

plt.title("Living Area vs House Sale Price")
plt.xlabel("Above Ground Living Area")
plt.ylabel("Sale Price")

plt.savefig(
    "../reports/living_area_vs_price.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
X = df.drop("SalePrice", axis=1)
y = df["SalePrice"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (1460, 80)
# Target shape: (1460,)

# %%
numerical_features = X.select_dtypes(
    include=["int64", "float64"]
).columns

categorical_features = X.select_dtypes(
    include=["object"]
).columns

print("Numerical features:", len(numerical_features))
print("Categorical features:", len(categorical_features))

print("\nCategorical features:")
print(categorical_features.tolist())
# Out:
# Numerical features: 37
# Categorical features: 43
#
# Categorical features:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (1168, 80)
# Testing data: (292, 80)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median"))
    ]
)

categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore"))
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

print("Preprocessing pipeline created successfully!")
# Out:
# Preprocessing pipeline created successfully!

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

linear_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LinearRegression())
    ]
)

random_forest_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", RandomForestRegressor(
            n_estimators=300,
            random_state=42,
            n_jobs=-1
        ))
    ]
)

print("Two ML models created successfully!")
print("1. Linear Regression")
print("2. Random Forest Regressor")
# Out:
# Two ML models created successfully!
# 1. Linear Regression
# 2. Random Forest Regressor

# %%
print("Training Linear Regression...")
linear_model.fit(X_train, y_train)

print("Training Random Forest...")
random_forest_model.fit(X_train, y_train)

print("Both models trained successfully!")
# Out:
# Training Linear Regression...
# Training Random Forest...
# Both models trained successfully!

# %%
linear_predictions = linear_model.predict(X_test)
rf_predictions = random_forest_model.predict(X_test)

print("Predictions generated successfully!")
print("Number of test samples:", len(y_test))
# Out:
# Predictions generated successfully!
# Number of test samples: 292

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

def evaluate_model(model_name, actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    r2 = r2_score(actual, predicted)

    print(f"\n{model_name}")
    print("-" * 40)
    print(f"MAE  : {mae:,.2f}")
    print(f"RMSE : {rmse:,.2f}")
    print(f"R²   : {r2:.4f}")

    return mae, rmse, r2

linear_results = evaluate_model(
    "Linear Regression",
    y_test,
    linear_predictions
)

rf_results = evaluate_model(
    "Random Forest Regressor",
    y_test,
    rf_predictions
)
# Out:
# Linear Regression
# ----------------------------------------
# MAE  : 20,485.66
# RMSE : 31,327.80
# R²   : 0.8720
#
# Random Forest Regressor
# ----------------------------------------
# MAE  : 17,465.29
# RMSE : 28,554.98
# R²   : 0.8937

# %%
results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest Regressor"
    ],
    "MAE": [
        linear_results[0],
        rf_results[0]
    ],
    "RMSE": [
        linear_results[1],
        rf_results[1]
    ],
    "R2 Score": [
        linear_results[2],
        rf_results[2]
    ]
})

results
# Out:
#                      Model           MAE          RMSE  R2 Score
# 0        Linear Regression  20485.659297  31327.795381  0.872048
# 1  Random Forest Regressor  17465.290365  28554.982875  0.893696

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    y_test,
    rf_predictions,
    alpha=0.6
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.title("Actual vs Predicted House Prices - Random Forest")
plt.xlabel("Actual Sale Price")
plt.ylabel("Predicted Sale Price")

plt.savefig(
    "../reports/actual_vs_predicted.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
prediction_errors = y_test - rf_predictions

plt.figure(figsize=(10, 6))

sns.histplot(prediction_errors, kde=True)

plt.title("Distribution of Prediction Errors")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")

plt.savefig(
    "../reports/prediction_errors.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
feature_names = (
    random_forest_model
    .named_steps["preprocessor"]
    .get_feature_names_out()
)

feature_importances = (
    random_forest_model
    .named_steps["model"]
    .feature_importances_
)

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importances
})

importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df.head(15)
# Out:
#                Feature  Importance
# 4     num__OverallQual    0.555564
# 16      num__GrLivArea    0.121834
# 12    num__TotalBsmtSF    0.033275
# 14       num__2ndFlrSF    0.031765
# 9      num__BsmtFinSF1    0.028104
# 13       num__1stFlrSF    0.025742
# 3         num__LotArea    0.017800
# 27     num__GarageArea    0.015538
# 26     num__GarageCars    0.013683
# 6       num__YearBuilt    0.011759
# 2     num__LotFrontage    0.008038
# 7    num__YearRemodAdd    0.006753
# 181   cat__BsmtQual_Ex    0.006423
# 19       num__FullBath    0.006255
# 23   num__TotRmsAbvGrd    0.005787

# %%
top_features = importance_df.head(15).sort_values(
    by="Importance"
)

plt.figure(figsize=(10, 7))

plt.barh(
    top_features["Feature"],
    top_features["Importance"]
)

plt.title("Top 15 Important Features for House Price Prediction")
plt.xlabel("Feature Importance")
plt.ylabel("Feature")

plt.savefig(
    "../reports/feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
sample_house = X_test.iloc[[0]]

predicted_price = random_forest_model.predict(sample_house)[0]
actual_price = y_test.iloc[0]

print(f"Actual House Price    : ${actual_price:,.2f}")
print(f"Predicted House Price : ${predicted_price:,.2f}")
# Out:
# Actual House Price    : $154,500.00
# Predicted House Price : $140,643.21

# %%
best_model_name = results.loc[
    results["R2 Score"].idxmax(), "Model"
]

print("Best performing model based on R²:")
print(best_model_name)
# Out:
# Best performing model based on R²:
# Random Forest Regressor

# %%
import joblib

joblib.dump(
    random_forest_model,
    "../models/house_price_prediction_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
loaded_model = joblib.load(
    "../models/house_price_prediction_model.pkl"
)

test_prediction = loaded_model.predict(X_test.iloc[[0]])[0]

print(f"Test Prediction: ${test_prediction:,.2f}")
print("Saved model loaded successfully!")
# Out:
# Test Prediction: $140,643.21
# Saved model loaded successfully!

# %%
print("========== HOUSE PRICE PREDICTION MODEL ==========")
print(f"Model: Random Forest Regressor")
print(f"MAE : ${rf_results[0]:,.2f}")
print(f"RMSE: ${rf_results[1]:,.2f}")
print(f"R²  : {rf_results[2]:.4f}")
print("===================================================")
# Out:
# ========== HOUSE PRICE PREDICTION MODEL ==========
# Model: Random Forest Regressor
# MAE : $17,465.29
# RMSE: $28,554.98
# R²  : 0.8937
# ...

# %%
print("KEY PROJECT FINDINGS")
print("--------------------")
print("1. House prices were analyzed using exploratory data analysis.")
print("2. Missing values and categorical features were handled using a preprocessing pipeline.")
print("3. Linear Regression and Random Forest Regression were evaluated.")
print("4. Random Forest was evaluated using MAE, RMSE and R².")
print("5. Feature importance was analyzed to understand important predictors.")
print("6. The trained model was saved for future predictions.")
# Out:
# KEY PROJECT FINDINGS
# --------------------
# 1. House prices were analyzed using exploratory data analysis.
# 2. Missing values and categorical features were handled using a preprocessing pipeline.
# 3. Linear Regression and Random Forest Regression were evaluated.
# 4. Random Forest was evaluated using MAE, RMSE and R².
# 5. Feature importance was analyzed to understand important predictors.
# 6. The trained model was saved for future predictions.
